# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('/content/drive/MyDrive/sales_data_sample.csv', encoding='latin1')

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
print("Missing values:\n", data.isnull().sum())
# Out:
# Missing values:
#  ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
selected_features = data[['SALES', 'QUANTITYORDERED']].copy()

# %%
scaler = StandardScaler()
selected_features_scaled = scaler.fit_transform(selected_features)

# %%
inertia = []

# %%
cluster_range = range(1, 11)

# %%
for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(selected_features_scaled)
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 5))
plt.plot(cluster_range, inertia, marker='o', linestyle='-')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia (Sum of Squared Distances)')
plt.title('Elbow Method to Determine Optimal Number of Clusters')
plt.show()

# %%
optimal_k = 3

# %%
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(selected_features_scaled)

# %%
data['Cluster'] = clusters

# %%
print(data[['SALES', 'QUANTITYORDERED', 'Cluster']].head())
# Out:
#      SALES  QUANTITYORDERED  Cluster
# 0  2871.00               30        0
# 1  2765.90               34        1
# 2  3884.34               41        1
# 3  3746.70               45        1
# 4  5205.27               49        2

# %%
plt.figure(figsize=(8, 5))
plt.scatter(selected_features_scaled[:, 0], selected_features_scaled[:, 1], c=clusters, cmap='viridis', marker='o')
plt.xlabel('SALES (Standardized)')
plt.ylabel('QUANTITYORDERED (Standardized)')
plt.title('K-Means Clustering Results')
plt.colorbar(label='Cluster')
plt.show()
